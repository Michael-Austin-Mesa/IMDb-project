# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

# %%
data=pd.read_csv('Genre Classification Dataset/train_data.txt', on_bad_lines='skip')

# %%
data.T
# Out:
#                                                                                                 0      \
# 1 ::: Oscar et la dame rose (2009) ::: drama ::...  2 ::: Cupid (1997) ::: thriller ::: A brother ...
#  10-year-old Oscar learns what nobody has the c...                                                NaN
#  he refuses to speak to anyone except straight-...                                                NaN
#  the lady in pink he meets on the hospital stai...                                                NaN
#  Rose uses her fantastical experiences as a pro...                                                NaN
#  her imagination                                                                                  NaN
#  wit and charm to allow Oscar to live life and ...                                                NaN
#  in the company of his friends Pop Corn                                                           NaN
# ...
